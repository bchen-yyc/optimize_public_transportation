# %%
import pandas as pd
from models import Line, Weather, Station, Train, Turnstile

# %%
raw_df = pd.read_csv("data/cta_stations.csv").sort_values("order")

# %%
station_data = raw_df[raw_df["blue"]]

# %%
station_data.head()
# Out:
#     stop_id direction_id                   stop_name station_name  \
# 81    30171            N   O'Hare (Terminal Arrival)       O'Hare
# 80    30172            S    O'Hare (Forest Pk-bound)       O'Hare
# 93    30159            N     Rosemont (O'Hare-bound)     Rosemont
# 92    30160            S  Rosemont (Forest Pk-bound)     Rosemont
# 97    30044            N   Cumberland (O'Hare-bound)   Cumberland
#
#    station_descriptive_name  station_id  order    red  blue  green
# 81       O'Hare (Blue Line)       40890      0  False  True  False
# 80       O'Hare (Blue Line)       40890      0  False  True  False
# 93     Rosemont (Blue Line)       40820      1  False  True  False
# 92     Rosemont (Blue Line)       40820      1  False  True  False
# 97   Cumberland (Blue Line)       40230      2  False  True  False

# %%
line = Line(Line.colors.blue, station_data, 10);
# Out:
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic ohare_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic rosemont_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic rosemont_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic cumberland_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic cumberland_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic harlem_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic harlem_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic jefferson_park_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic jefferson_park_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic montrose_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic montrose_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic irving_park_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic irving_park_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic addison_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic addison_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic belmont_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic belmont_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic logan_square_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic logan_square_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic california_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic california_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic western_and_ohare_branch_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic western_and_ohare_branch_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic damen_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic damen_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic division_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic division_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic chicago_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic chicago_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic grand_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic grand_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic clark_and_lake_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic clark_and_lake_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic washington_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic washington_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic monroe_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic monroe_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic jackson_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic jackson_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic lasalle_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic lasalle_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic clinton_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic clinton_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic uic_halsted_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic uic_halsted_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic racine_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic racine_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic illinois_medical_district_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic illinois_medical_district_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic western_and_forest_pk_branch_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic western_and_forest_pk_branch_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic kedzie_homan_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic kedzie_homan_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic pulaski_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic pulaski_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic cicero_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic cicero_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic austin_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic austin_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic oak_park_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic oak_park_turnstile!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic forest_park_arrival!!
# dict_keys(['_schemas', 'connect-configs', '_confluent-ksql-default__command_topic', 'com.udacity.streams.pages', 'connect-status', 'connect-offsets', '__consumer_offsets', 'com.udacity.streams.users', '_confluent-metrics', 'ohare_arrival', 'com.udacity.streams.clickevents', 'com.udacity.streams.purchases', '__confluent.support.metrics'])
# created new topic forest_park_turnstile!!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-6724e685f894> in <module>
# ----> 1 line = Line(Line.colors.blue, station_data, 10);
#
# /home/workspace/producers/models/line.py in __init__(self, color, station_data, num_trains)
#      22         # We must always discount the terminal station at the end of each direction
#      23         self.num_stations = len(self.stations) - 1
# ---> 24         #self.trains = self._build_trains()
#      25
#      26     def _build_line_data(self, station_df):
#
# /home/workspace/producers/models/line.py in _build_trains(self)
#      59
#      60             if b_dir:
# ---> 61                 self.stations[curr_loc].arrive_b(train, None, None)
#      62             else:
#      63                 self.stations[curr_loc].arrive_a(train, None, None)
#
# /home/workspace/producers/models/station.py in arrive_b(self, train, prev_station_id, prev_direction)
#      89         """Denotes a train arrival at this station in the 'b' direction"""
#      90         self.b_train = train
# ---> 91         self.run(train, "b", prev_station_id, prev_direction)
#      92
#      93     def close(self):
#
# /home/workspace/producers/models/station.py in run(self, train, direction, prev_station_id, prev_direction)
#      64                 "train_status": train.status.name,
#      65                 "prev_station_id": prev_station_id,
# ---> 66                 "prev_direction": prev_direction
#      67             },
#      68         )
#
# /opt/conda/lib/python3.7/site-packages/confluent_kafka/avro/__init__.py in produce(self, **kwargs)
#      78         if value is not None:
#      79             if value_schema:
# ---> 80                 value = self._serializer.encode_record_with_schema(topic, value_schema, value)
#      81             else:
#      82                 raise ValueSerializerError("Avro schema required for values")
#
# /opt/conda/lib/python3.7/site-packages/confluent_kafka/avro/serializer/message_serializer.py in encode_record_with_schema(self, topic, schema, record, is_key)
#     111         self.id_to_writers[schema_id] = self._get_encoder_func(schema)
#     112
# --> 113         return self.encode_record_with_schema_id(schema_id, record, is_key=is_key)
#     114
#     115     def encode_record_with_schema_id(self, schema_id, record, is_key=False):
#
# /opt/conda/lib/python3.7/site-packages/confluent_kafka/avro/serializer/message_serializer.py in encode_record_with_schema_id(self, schema_id, record, is_key)
#     145
#     146             # write the record to the rest of the buffer
# --> 147             writer(record, outf)
#     148
#     149             return outf.getvalue()
#
# /opt/conda/lib/python3.7/site-packages/confluent_kafka/avro/serializer/message_serializer.py in <lambda>(record, fp)
#      80         if HAS_FAST:
#      81             schema = writer_schema.to_json()
# ---> 82             return lambda record, fp: schemaless_writer(fp, schema, record)
#      83         writer = avro.io.DatumWriter(writer_schema)
#      84         return lambda record, fp: writer.write(record, avro.io.BinaryEncoder(fp))
#
# fastavro/_write.pyx in fastavro._write.schemaless_writer()
#
# fastavro/_write.pyx in fastavro._write.write_data()
#
# fastavro/_write.pyx in fastavro._write.write_record()
#
# fastavro/_write.pyx in fastavro._write.write_data()
#
# fastavro/_write.pyx in fastavro._write.write_utf8()
#
# AttributeError: 'int' object has no attribute 'encode'
